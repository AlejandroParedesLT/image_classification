# %% [markdown]
# #  AIPI 590 Applied Machine Learning
#
# ### Alejandro Paredes La Torre

# %%
import numpy as np
import pandas as pd
import glob
import math
import os
import torch
import random
from torchvision import datasets, transforms, models
from torch import nn, optim
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
from PIL import Image
from pathlib import Path
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'


# Specify the device type
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# %%
# Get the total number of images in each class
file_count = 0
classes = os.listdir("C:/Users/ALEJANDRO/Documents/7. DUKE/1. AIPI 590 - Computer Vision/assignment/First_group_project/data/train_data")
print('Classes:',len(classes))
for cat in ['train_data', 'test_data']: #'val',
  files = glob.glob('C:/Users/ALEJANDRO/Documents/7. DUKE/1. AIPI 590 - Computer Vision/assignment/First_group_project/data/'+cat+'/*/*')
  print(cat,'Images:',len(files), end = ', ')
print('\n')
for direc in classes:
  files = glob.glob('C:/Users/ALEJANDRO/Documents/7. DUKE/1. AIPI 590 - Computer Vision/assignment/First_group_project/data/*/'+direc+'/*')
  file_count += len(files)
  print(direc, len(files))
print(file_count)
# Out:
# Classes: 5
# train_data Images: 25000, test_data Images: 500,
#
# airport_terminal 5100
# aquarium 5100
# bar 5100
# beach 5100
# music_studio 5100
# 25500

# %% [markdown]
# ## **Load The Data**

# %%
data_dir = "C:/Users/ALEJANDRO/Documents/7. DUKE/1. AIPI 590 - Computer Vision/assignment/First_group_project/data"
random.seed(41)

#Data Tranforms (Augmentation and Normalization)
train_transforms = transforms.Compose([
                                       transforms.RandomRotation(30),
                                       transforms.RandomPerspective(distortion_scale=0.4),
                                       transforms.RandomHorizontalFlip(0.6),
                                       transforms.Resize(size=(224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])])
val_transforms = transforms.Compose([
                                       transforms.RandomRotation(30),
                                       transforms.RandomHorizontalFlip(0.6),
                                       transforms.Resize(size=(224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])])
test_transforms = transforms.Compose([transforms.Resize(size=(224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])])

#Getting all the data with PyTorch Datasets
train_data = datasets.ImageFolder(data_dir + '/train_data', transform= train_transforms)
val_data = datasets.ImageFolder(data_dir + '/test_data', transform= val_transforms)
test_data = datasets.ImageFolder(data_dir + '/test_data', transform= test_transforms)

#Loading the data into PyTorch DataLoader
train_loader = torch.utils.data.DataLoader(train_data, batch_size= 128, shuffle = True,num_workers=2)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size= 64, shuffle = True,num_workers=2)
test_loader = torch.utils.data.DataLoader(test_data, batch_size= 64, shuffle = True,num_workers=2)

#Creating a dictionary of all classes
classes = dict(zip(list(range(len(train_data.classes))),train_data.classes))

# %% [markdown]
# ### **Check the images with labels**

# %%
def denormalise(image):
    try:
        image = image.cpu().numpy().transpose(1, 2, 0)
    except:
        image = image.transpose(1, 2, 0)  # PIL images have channel last
    mean = [0.485, 0.456, 0.406]
    stdd = [0.229, 0.224, 0.225]
    image = (image * stdd + mean).clip(0, 1)
    return image

dataiter = iter(train_loader)
images, labels = next(dataiter)  # Use next() instead of dataiter.next()
images = images.numpy()
fig = plt.figure(figsize=(15, 15))

for idx in np.arange(25):
    ax = fig.add_subplot(5, 5, idx + 1, xticks=[], yticks=[])
    ax.imshow(denormalise(images[idx]), cmap='gray')
    ax.set_title(classes[labels[idx].item()])

# %% [markdown]
# ## **Load the model**

# %%
model = models.resnet50(pretrained=True)
for param in model.parameters():
    param.requires_grad = False

model.avgpool = nn.AdaptiveAvgPool2d(output_size=(1,1))
model.classifier = nn.Sequential(
    #nn.Flatten(),
    nn.Linear(2048, 512),
    nn.Dropout(0.6),
    nn.ReLU(),
    nn.Linear(512,256),
    nn.Dropout(0.5),
    nn.ReLU(),
    nn.Linear(256, 128),
    nn.Dropout(0.4),
    nn.ReLU(),
    nn.Linear(128,len(classes))
)
# Unfreeze the classifier layer for training
for param in model.fc.parameters():
    param.requires_grad = True

# Move the entire model (including the classifier) to the GPU
model = model.to(device)

# %% [markdown]
# ### **Specify the Loss Criterion, Optimizer and Scheduler**

# %%
criterion = nn.CrossEntropyLoss()
optimizer  = optim.Adam(model.fc.parameters(), lr=1e-4)
scheduler = StepLR(optimizer, step_size=2, gamma=0.35)

# %% [markdown]
# ## **Train The Model**

# %%
epochs = 10 # Number of epochs
steps = 0
print_every = 5 
train_losses, valid_losses,valid_acc = [], [], [] # List keeping track of losses and accuracy to plot later
valid_loss_min = np.inf # It will be used to save model whenever Vallidation loss decreases
valid_acc_min = 0.0 

for e in range(epochs):
  
  train_loss = 0 
  model.train()
  #train the model
  for images, labels in train_loader:
    steps+=1
    # Move tensor to device('cuda' in case of GPU or 'cpu' in case of CPU)
    images, labels = images.to(device), labels.to(device)
    # Clearing all the previous gradients
    optimizer.zero_grad()
    # Forward Pass
    logits = model(images)
    # Loss calculation
    loss = criterion(logits,labels)
    # Backward Pass
    loss.backward()
    # Update the parameters
    optimizer.step()
    # Updating the losses list
    train_loss += loss.item()


    # Evaluating after specific amount of steps
    if steps % print_every == 0:
      valid_loss = 0
      accuracy = 0
      # Setting Model to Evaluation Mode
      model.eval()
      with torch.no_grad():
        # Getting Validation loss
        for images, labels in valid_loader:
          images, labels = images.to(device), labels.to(device)
          logits = model(images)
          batch_loss = criterion(logits,labels)
          valid_loss += batch_loss.item()
          
          # Calculating Accuracy
          output = F.softmax(logits,dim=1)
          top_p,top_class = output.topk(1,dim = 1)
          equals = top_class == labels.view(*top_class.shape)
          accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
      # Printing stats    
      print(f"Epoch {e+1}/{epochs}.. "
                  f"Train loss: {train_loss/print_every:.3f}.. "
                  f"Validation loss: {valid_loss/len(valid_loader):.3f}.. "
                  f"Validation accuracy: {accuracy/len(valid_loader):.3f}.. "
                  f"LR : {scheduler.get_lr():}"
                  )
      valid_loss = valid_loss/len(valid_loader)
      train_losses.append(train_loss/print_every)
      valid_losses.append(valid_loss)
      valid_acc.append(accuracy/len(valid_loader))
      
      # Checking if Validation loss decreased
      if valid_loss <= valid_loss_min:
        
        # if decreased, it will save the model
        print('valid loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'C:/Users/ALEJANDRO/Documents/7. DUKE/1. AIPI 590 - Computer Vision/assignment/First_group_project/scenes_resnet50.pt')
        valid_loss_min = valid_loss
      
      
  # Scheduler performing a step to change learning rate of Optimizer    
  scheduler.step()
# Out:
# c:\Users\ALEJANDRO\Documents\5. Programming\.virtualenvs\aplt_duke\lib\site-packages\torch\optim\lr_scheduler.py:525: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   _warn_get_lr_called_within_step(self)
# Epoch 1/10.. Train loss: 9.543.. Validation loss: 9.890.. Validation accuracy: 0.016.. LR : [0.0001]
# valid loss decreased (inf --> 9.889924).  Saving model ...
# Epoch 1/10.. Train loss: 19.019.. Validation loss: 8.916.. Validation accuracy: 0.015.. LR : [0.0001]
# valid loss decreased (9.889924 --> 8.916339).  Saving model ...
# Epoch 1/10.. Train loss: 27.632.. Validation loss: 8.198.. Validation accuracy: 0.018.. LR : [0.0001]
# valid loss decreased (8.916339 --> 8.198151).  Saving model ...
# Epoch 1/10.. Train loss: 35.585.. Validation loss: 7.529.. Validation accuracy: 0.024.. LR : [0.0001]
# valid loss decreased (8.198151 --> 7.528771).  Saving model ...
# Epoch 1/10.. Train loss: 42.923.. Validation loss: 6.683.. Validation accuracy: 0.041.. LR : [0.0001]
# valid loss decreased (7.528771 --> 6.682927).  Saving model ...
# Epoch 1/10.. Train loss: 49.392.. Validation loss: 6.064.. Validation accuracy: 0.049.. LR : [0.0001]
# valid loss decreased (6.682927 --> 6.064438).  Saving model ...
# Epoch 1/10.. Train loss: 55.204.. Validation loss: 5.360.. Validation accuracy: 0.063.. LR : [0.0001]
# valid loss decreased (6.064438 --> 5.360115).  Saving model ...
# Epoch 1/10.. Train loss: 60.338.. Validation loss: 4.742.. Validation accuracy: 0.103.. LR : [0.0001]
# valid loss decreased (5.360115 --> 4.741736).  Saving model ...
# Epoch 1/10.. Train loss: 64.990.. Validation loss: 4.208.. Validation accuracy: 0.113.. LR : [0.0001]
# valid loss decreased (4.741736 --> 4.207917).  Saving model ...
# Epoch 1/10.. Train loss: 69.057.. Validation loss: 3.766.. Validation accuracy: 0.150.. LR : [0.0001]
# valid loss decreased (4.207917 --> 3.765966).  Saving model ...
# Epoch 1/10.. Train loss: 72.656.. Validation loss: 3.422.. Validation accuracy: 0.169.. LR : [0.0001]
# valid loss decreased (3.765966 --> 3.421890).  Saving model ...
# Epoch 1/10.. Train loss: 75.951.. Validation loss: 3.135.. Validation accuracy: 0.178.. LR : [0.0001]
# valid loss decreased (3.421890 --> 3.134907).  Saving model ...
# Epoch 1/10.. Train loss: 79.068.. Validation loss: 2.835.. Validation accuracy: 0.205.. LR : [0.0001]
# valid loss decreased (3.134907 --> 2.834671).  Saving model ...
# Epoch 1/10.. Train loss: 81.967.. Validation loss: 2.743.. Validation accuracy: 0.228.. LR : [0.0001]
# valid loss decreased (2.834671 --> 2.743035).  Saving model ...
# Epoch 1/10.. Train loss: 84.700.. Validation loss: 2.643.. Validation accuracy: 0.224.. LR : [0.0001]
# valid loss decreased (2.743035 --> 2.642610).  Saving model ...
# Epoch 1/10.. Train loss: 87.360.. Validation loss: 2.445.. Validation accuracy: 0.271.. LR : [0.0001]
# valid loss decreased (2.642610 --> 2.444917).  Saving model ...
# Epoch 1/10.. Train loss: 89.822.. Validation loss: 2.357.. Validation accuracy: 0.274.. LR : [0.0001]
# valid loss decreased (2.444917 --> 2.357141).  Saving model ...
# Epoch 1/10.. Train loss: 92.243.. Validation loss: 2.366.. Validation accuracy: 0.268.. LR : [0.0001]
# Epoch 1/10.. Train loss: 94.607.. Validation loss: 2.221.. Validation accuracy: 0.271.. LR : [0.0001]
# valid loss decreased (2.357141 --> 2.221034).  Saving model ...
# Epoch 1/10.. Train loss: 96.994.. Validation loss: 2.216.. Validation accuracy: 0.316.. LR : [0.0001]
# valid loss decreased (2.221034 --> 2.216091).  Saving model ...
# Epoch 1/10.. Train loss: 99.198.. Validation loss: 2.218.. Validation accuracy: 0.313.. LR : [0.0001]
# Epoch 1/10.. Train loss: 101.321.. Validation loss: 2.128.. Validation accuracy: 0.330.. LR : [0.0001]
# valid loss decreased (2.216091 --> 2.127830).  Saving model ...
# Epoch 1/10.. Train loss: 103.521.. Validation loss: 2.032.. Validation accuracy: 0.319.. LR : [0.0001]
# valid loss decreased (2.127830 --> 2.031775).  Saving model ...
# Epoch 1/10.. Train loss: 105.680.. Validation loss: 2.005.. Validation accuracy: 0.345.. LR : [0.0001]
# valid loss decreased (2.031775 --> 2.005489).  Saving model ...
# Epoch 1/10.. Train loss: 107.766.. Validation loss: 1.995.. Validation accuracy: 0.324.. LR : [0.0001]
# valid loss decreased (2.005489 --> 1.994630).  Saving model ...
# Epoch 1/10.. Train loss: 109.718.. Validation loss: 1.936.. Validation accuracy: 0.369.. LR : [0.0001]
# valid loss decreased (1.994630 --> 1.935543).  Saving model ...
# Epoch 1/10.. Train loss: 111.749.. Validation loss: 1.930.. Validation accuracy: 0.345.. LR : [0.0001]
# valid loss decreased (1.935543 --> 1.929895).  Saving model ...
# Epoch 1/10.. Train loss: 113.769.. Validation loss: 1.860.. Validation accuracy: 0.361.. LR : [0.0001]
# valid loss decreased (1.929895 --> 1.860286).  Saving model ...
# Epoch 1/10.. Train loss: 115.627.. Validation loss: 1.811.. Validation accuracy: 0.370.. LR : [0.0001]
# valid loss decreased (1.860286 --> 1.811440).  Saving model ...
# Epoch 1/10.. Train loss: 117.506.. Validation loss: 1.765.. Validation accuracy: 0.385.. LR : [0.0001]
# valid loss decreased (1.811440 --> 1.765057).  Saving model ...
# Epoch 1/10.. Train loss: 119.404.. Validation loss: 1.762.. Validation accuracy: 0.395.. LR : [0.0001]
# valid loss decreased (1.765057 --> 1.761598).  Saving model ...
# Epoch 1/10.. Train loss: 121.258.. Validation loss: 1.722.. Validation accuracy: 0.401.. LR : [0.0001]
# valid loss decreased (1.761598 --> 1.722210).  Saving model ...
# Epoch 1/10.. Train loss: 123.160.. Validation loss: 1.678.. Validation accuracy: 0.399.. LR : [0.0001]
# valid loss decreased (1.722210 --> 1.678122).  Saving model ...
# Epoch 1/10.. Train loss: 124.890.. Validation loss: 1.691.. Validation accuracy: 0.416.. LR : [0.0001]
# Epoch 1/10.. Train loss: 126.576.. Validation loss: 1.674.. Validation accuracy: 0.438.. LR : [0.0001]
# valid loss decreased (1.678122 --> 1.673836).  Saving model ...
# Epoch 1/10.. Train loss: 128.348.. Validation loss: 1.631.. Validation accuracy: 0.436.. LR : [0.0001]
# valid loss decreased (1.673836 --> 1.630639).  Saving model ...
# Epoch 1/10.. Train loss: 130.023.. Validation loss: 1.601.. Validation accuracy: 0.450.. LR : [0.0001]
# valid loss decreased (1.630639 --> 1.600609).  Saving model ...
# Epoch 1/10.. Train loss: 131.672.. Validation loss: 1.552.. Validation accuracy: 0.445.. LR : [0.0001]
# valid loss decreased (1.600609 --> 1.552439).  Saving model ...
# Epoch 1/10.. Train loss: 133.267.. Validation loss: 1.516.. Validation accuracy: 0.473.. LR : [0.0001]
# valid loss decreased (1.552439 --> 1.516281).  Saving model ...
# Epoch 2/10.. Train loss: 1.245.. Validation loss: 1.508.. Validation accuracy: 0.470.. LR : [0.0001]
# valid loss decreased (1.516281 --> 1.508042).  Saving model ...
# Epoch 2/10.. Train loss: 2.771.. Validation loss: 1.466.. Validation accuracy: 0.475.. LR : [0.0001]
# valid loss decreased (1.508042 --> 1.466267).  Saving model ...
# Epoch 2/10.. Train loss: 4.339.. Validation loss: 1.475.. Validation accuracy: 0.469.. LR : [0.0001]
# Epoch 2/10.. Train loss: 5.902.. Validation loss: 1.482.. Validation accuracy: 0.485.. LR : [0.0001]
# Epoch 2/10.. Train loss: 7.390.. Validation loss: 1.441.. Validation accuracy: 0.493.. LR : [0.0001]
# valid loss decreased (1.466267 --> 1.440684).  Saving model ...
# Epoch 2/10.. Train loss: 8.926.. Validation loss: 1.424.. Validation accuracy: 0.480.. LR : [0.0001]
# valid loss decreased (1.440684 --> 1.424075).  Saving model ...
# Epoch 2/10.. Train loss: 10.483.. Validation loss: 1.381.. Validation accuracy: 0.516.. LR : [0.0001]
# valid loss decreased (1.424075 --> 1.381060).  Saving model ...
# Epoch 2/10.. Train loss: 12.041.. Validation loss: 1.410.. Validation accuracy: 0.496.. LR : [0.0001]
# Epoch 2/10.. Train loss: 13.525.. Validation loss: 1.394.. Validation accuracy: 0.503.. LR : [0.0001]
# Epoch 2/10.. Train loss: 14.852.. Validation loss: 1.351.. Validation accuracy: 0.505.. LR : [0.0001]
# valid loss decreased (1.381060 --> 1.351467).  Saving model ...
# Epoch 2/10.. Train loss: 16.309.. Validation loss: 1.306.. Validation accuracy: 0.540.. LR : [0.0001]
# valid loss decreased (1.351467 --> 1.306145).  Saving model ...
# Epoch 2/10.. Train loss: 17.647.. Validation loss: 1.311.. Validation accuracy: 0.523.. LR : [0.0001]
# Epoch 2/10.. Train loss: 18.926.. Validation loss: 1.298.. Validation accuracy: 0.532.. LR : [0.0001]
# valid loss decreased (1.306145 --> 1.297673).  Saving model ...
# Epoch 2/10.. Train loss: 20.317.. Validation loss: 1.283.. Validation accuracy: 0.542.. LR : [0.0001]
# valid loss decreased (1.297673 --> 1.283486).  Saving model ...
# Epoch 2/10.. Train loss: 21.661.. Validation loss: 1.242.. Validation accuracy: 0.558.. LR : [0.0001]
# valid loss decreased (1.283486 --> 1.241618).  Saving model ...
# Epoch 2/10.. Train loss: 22.980.. Validation loss: 1.217.. Validation accuracy: 0.573.. LR : [0.0001]
# valid loss decreased (1.241618 --> 1.216981).  Saving model ...
# Epoch 2/10.. Train loss: 24.247.. Validation loss: 1.200.. Validation accuracy: 0.574.. LR : [0.0001]
# valid loss decreased (1.216981 --> 1.200368).  Saving model ...
# Epoch 2/10.. Train loss: 25.494.. Validation loss: 1.194.. Validation accuracy: 0.565.. LR : [0.0001]
# valid loss decreased (1.200368 --> 1.194469).  Saving model ...
# Epoch 2/10.. Train loss: 26.712.. Validation loss: 1.131.. Validation accuracy: 0.586.. LR : [0.0001]
# valid loss decreased (1.194469 --> 1.130934).  Saving model ...
# Epoch 2/10.. Train loss: 27.965.. Validation loss: 1.142.. Validation accuracy: 0.592.. LR : [0.0001]
# Epoch 2/10.. Train loss: 29.135.. Validation loss: 1.154.. Validation accuracy: 0.590.. LR : [0.0001]
# Epoch 2/10.. Train loss: 30.386.. Validation loss: 1.155.. Validation accuracy: 0.581.. LR : [0.0001]
# Epoch 2/10.. Train loss: 31.587.. Validation loss: 1.103.. Validation accuracy: 0.622.. LR : [0.0001]
# valid loss decreased (1.130934 --> 1.103365).  Saving model ...
# Epoch 2/10.. Train loss: 32.863.. Validation loss: 1.091.. Validation accuracy: 0.615.. LR : [0.0001]
# valid loss decreased (1.103365 --> 1.091241).  Saving model ...
# Epoch 2/10.. Train loss: 34.011.. Validation loss: 1.121.. Validation accuracy: 0.569.. LR : [0.0001]
# Epoch 2/10.. Train loss: 35.182.. Validation loss: 1.081.. Validation accuracy: 0.578.. LR : [0.0001]
# valid loss decreased (1.091241 --> 1.081406).  Saving model ...
# Epoch 2/10.. Train loss: 36.324.. Validation loss: 1.036.. Validation accuracy: 0.639.. LR : [0.0001]
# valid loss decreased (1.081406 --> 1.036459).  Saving model ...
# Epoch 2/10.. Train loss: 37.423.. Validation loss: 1.028.. Validation accuracy: 0.629.. LR : [0.0001]
# valid loss decreased (1.036459 --> 1.027573).  Saving model ...
# Epoch 2/10.. Train loss: 38.471.. Validation loss: 1.021.. Validation accuracy: 0.636.. LR : [0.0001]
# valid loss decreased (1.027573 --> 1.020847).  Saving model ...
# Epoch 2/10.. Train loss: 39.545.. Validation loss: 1.060.. Validation accuracy: 0.600.. LR : [0.0001]
# Epoch 2/10.. Train loss: 40.642.. Validation loss: 1.021.. Validation accuracy: 0.650.. LR : [0.0001]
# Epoch 2/10.. Train loss: 41.733.. Validation loss: 0.950.. Validation accuracy: 0.663.. LR : [0.0001]
# valid loss decreased (1.020847 --> 0.949512).  Saving model ...
# Epoch 2/10.. Train loss: 42.867.. Validation loss: 1.019.. Validation accuracy: 0.626.. LR : [0.0001]
# Epoch 2/10.. Train loss: 43.872.. Validation loss: 0.986.. Validation accuracy: 0.666.. LR : [0.0001]
# Epoch 2/10.. Train loss: 44.937.. Validation loss: 0.988.. Validation accuracy: 0.641.. LR : [0.0001]
# Epoch 2/10.. Train loss: 45.946.. Validation loss: 0.904.. Validation accuracy: 0.675.. LR : [0.0001]
# valid loss decreased (0.949512 --> 0.904263).  Saving model ...
# Epoch 2/10.. Train loss: 46.877.. Validation loss: 0.957.. Validation accuracy: 0.636.. LR : [0.0001]
# Epoch 2/10.. Train loss: 47.966.. Validation loss: 0.897.. Validation accuracy: 0.674.. LR : [0.0001]
# valid loss decreased (0.904263 --> 0.896683).  Saving model ...
# Epoch 2/10.. Train loss: 48.948.. Validation loss: 0.918.. Validation accuracy: 0.683.. LR : [0.0001]
# Epoch 3/10.. Train loss: 0.609.. Validation loss: 0.960.. Validation accuracy: 0.658.. LR : [1.2249999999999998e-05]
# Epoch 3/10.. Train loss: 1.528.. Validation loss: 0.950.. Validation accuracy: 0.647.. LR : [1.2249999999999998e-05]
# Epoch 3/10.. Train loss: 2.449.. Validation loss: 0.922.. Validation accuracy: 0.664.. LR : [1.2249999999999998e-05]
# Epoch 3/10.. Train loss:
. LR : [1.5006249999999997e-06]
# valid loss decreased (0.640448 --> 0.634656).  Saving model ...
# Epoch 10/10.. Train loss: 5.113.. Validation loss: 0.678.. Validation accuracy: 0.756.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 5.782.. Validation loss: 0.695.. Validation accuracy: 0.747.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 6.537.. Validation loss: 0.690.. Validation accuracy: 0.759.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 7.263.. Validation loss: 0.685.. Validation accuracy: 0.747.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 7.980.. Validation loss: 0.674.. Validation accuracy: 0.752.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 8.766.. Validation loss: 0.708.. Validation accuracy: 0.747.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 9.499.. Validation loss: 0.664.. Validation accuracy: 0.753.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 10.192.. Validation loss: 0.697.. Validation accuracy: 0.753.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 10.861.. Validation loss: 0.680.. Validation accuracy: 0.744.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 11.579.. Validation loss: 0.677.. Validation accuracy: 0.748.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 12.269.. Validation loss: 0.650.. Validation accuracy: 0.777.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 13.023.. Validation loss: 0.681.. Validation accuracy: 0.750.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 13.723.. Validation loss: 0.665.. Validation accuracy: 0.757.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 14.446.. Validation loss: 0.662.. Validation accuracy: 0.750.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 15.186.. Validation loss: 0.685.. Validation accuracy: 0.731.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 15.939.. Validation loss: 0.665.. Validation accuracy: 0.784.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 16.620.. Validation loss: 0.629.. Validation accuracy: 0.792.. LR : [1.5006249999999997e-06]
# valid loss decreased (0.634656 --> 0.629477).  Saving model ...
# Epoch 10/10.. Train loss: 17.389.. Validation loss: 0.621.. Validation accuracy: 0.786.. LR : [1.5006249999999997e-06]
# valid loss decreased (0.629477 --> 0.621322).  Saving model ...
# Epoch 10/10.. Train loss: 18.091.. Validation loss: 0.691.. Validation accuracy: 0.727.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 18.782.. Validation loss: 0.656.. Validation accuracy: 0.767.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 19.554.. Validation loss: 0.686.. Validation accuracy: 0.772.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 20.295.. Validation loss: 0.647.. Validation accuracy: 0.778.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 21.010.. Validation loss: 0.682.. Validation accuracy: 0.746.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 21.742.. Validation loss: 0.679.. Validation accuracy: 0.747.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 22.452.. Validation loss: 0.711.. Validation accuracy: 0.723.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 23.110.. Validation loss: 0.691.. Validation accuracy: 0.762.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 23.884.. Validation loss: 0.712.. Validation accuracy: 0.724.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 24.608.. Validation loss: 0.690.. Validation accuracy: 0.754.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 25.299.. Validation loss: 0.681.. Validation accuracy: 0.768.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 26.034.. Validation loss: 0.673.. Validation accuracy: 0.764.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 26.726.. Validation loss: 0.665.. Validation accuracy: 0.761.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 27.443.. Validation loss: 0.675.. Validation accuracy: 0.746.. LR : [1.5006249999999997e-06]
# Epoch 10/10.. Train loss: 28.129.. Validation loss: 0.659.. Validation accuracy: 0.778.. LR : [1.5006249999999997e-06]

# %% [markdown]
# ### **Analysis of Training and Validation Losses and Accuracy**

# %%
model.load_state_dict(torch.load("C:/Users/ALEJANDRO/Documents/7. DUKE/1. AIPI 590 - Computer Vision/assignment/First_group_project/scenes_resnet50.pt"))
# Out:
# C:\Users\ALEJANDRO\AppData\Local\Temp\ipykernel_11476\3453914816.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("C:/Users/ALEJANDRO/Documents/7. DUKE/1. AIPI 590 - Computer Vision/assignment/First_group_project/CV_Places365/scenes_resnet50.pt"))
# <All keys matched successfully>

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.legend(frameon=False)

# %%
plt.plot(valid_acc, label='Validation Accuracy')
plt.legend(frameon=False)

# %% [markdown]
# ## **Model Evaluation**

# %%
model.eval() # Prep model for Evaluation

mean_of = 5 # Mean of how many evaluations
valid_loss = 0.0
class_correct = list(0. for i in range(len(classes))) # List of number of correct predictions in each class
class_total = list(0. for i in range(len(classes))) # List of total number of samples in each class

for i in range(mean_of):
  for data, target in test_loader:
    # Move the data to device
    data, target = data.to(device), target.to(device)
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    valid_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    
    # calculate test accuracy for each object class
    for i in range(len(target)):    
        label = target.data[i]
        if len(target) == 1:
          class_correct[label] += correct.item()
        else:
          class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate and print average test loss
valid_loss = valid_loss/(mean_of * len(test_loader.dataset))
print('Test Loss: {:.6f}\n'.format(valid_loss))

# print accuracy of each class
for i in range(len(classes)):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %0.2f%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))
acc = 100. * np.sum(class_correct) / np.sum(class_total)

# print total accuracy of the model
print('\nTest Accuracy (Overall): %0.2f%% (%2d/%2d)' % (
    acc,
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.641686
#
# Test Accuracy of     0: 81.00% (405/500)
# Test Accuracy of     1: 69.00% (345/500)
# Test Accuracy of     2: 78.00% (390/500)
# Test Accuracy of     3: 97.00% (485/500)
# Test Accuracy of     4: 67.00% (335/500)
#
# Test Accuracy (Overall): 78.40% (1960/2500)

# %%
## To check on a custom Image

img = Image.open('C:/Users/ALEJANDRO/Documents/7. DUKE/1. AIPI 590 - Computer Vision/assignment/First_group_project/data/test_data/aquarium/Places365_val_00001341.jpg')
# Convert 2D image to 1D vector
images = test_transforms(img)

plt.imshow(denormalise(images))
# Calculate the class probabilities (softmax) for img
with torch.no_grad():
  images = images.to(device)
  output = model(images.unsqueeze(0))

ps = F.softmax(output, dim =1 )

classes[int(torch.argmax(ps).item())]
# Out:
# 'aquarium'

# %%
# Check which images, the model predicted incorrectly with correct and predicted label and the probability

classes
dataiter = iter(test_loader)
images, labels = next(dataiter)
with torch.no_grad():
  images, labels = images.to(device), labels.to(device)
  output = model(images)

ps = F.softmax(output, dim =1 )

#images = images.cpu().numpy()


fig = plt.figure(figsize=(25,16))
i = 1
for idx in np.arange(64):
  pred = torch.argmax(ps[idx]).item()
  prob = ps[idx][pred]
  if labels[idx].item() != pred:
    ax = fig.add_subplot(8, 8, i, xticks=[], yticks=[])
    ax.imshow(denormalise(images[idx]), cmap='gray')
    ax.set_title((str(labels[idx].item())+':'+str(pred))+', '+str(prob.item()))
    i+=1

# %%
import numpy as np
import torch
from sklearn.metrics import confusion_matrix
import seaborn as sns

import matplotlib.pyplot as plt
import torch.nn.functional as F

# Assuming 'test_loader' is your DataLoader and 'classes' contains the class names
all_preds = []
all_labels = []

# Iterate through the test dataset to gather predictions and labels
dataiter = iter(test_loader)
for images, labels in dataiter:
    with torch.no_grad():
        images, labels = images.to(device), labels.to(device)
        output = model(images)
        ps = F.softmax(output, dim=1)
    
    # Get predictions
    preds = torch.argmax(ps, dim=1)
    
    # Store predictions and true labels
    all_preds.extend(preds.cpu().numpy())
    all_labels.extend(labels.cpu().numpy())

# Create the confusion matrix
cm = confusion_matrix(all_labels, all_preds)

# Plotting the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=[classes[i] for i in range(len(classes))], 
            yticklabels=[classes[i] for i in range(len(classes))])
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')
plt.show()
